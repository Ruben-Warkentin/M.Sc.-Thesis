# %%
import MDAnalysis as mda #import MDAnalysis
from MDAnalysis.analysis import contacts #allows us to use contacts_within_cutoff

import os #allows us to move directories, needed for looping directories
import numpy as np #scientific computing package, for making arrays
import pandas as pd #data analysis module, for making data frames
import matplotlib.pyplot as plt #plotting module
import seaborn as sns
from math import *
##renders figures in a notebook
# %matplotlib inline

# %%
plt.rcParams['figure.dpi'] = 100 #lower  quality inline figure
plt.rcParams['savefig.dpi'] = 600 #high quality save file for publication

# %%
rad = 3.2 #the distance within two atoms are considered to be bonded

## Azimuthal angles around the z-axis, for a total of 14 segments
thetas = ['015', '045', '075', '105', '135', '165', '195', '225', '255', '285', '315', '345',]
dcd_thetas = ['15', '45', '75', '105', '135', '165', '195', '225', '255', '285', '315', '345',]
# z values at the center of each patch, from z = -22 to z = 27 Angstrom
zz = ['-24.24', '-17.31', '-10.39', '-3.46', '03.46', '10.39', '17.31', '24.24',]

#combined z and theta values
z_theta = []
z = []
theta = []
#creating a list of all simulations and their bonds
bcolumns = ['z','theta', 'Bonds']
sb_z_theta = pd.DataFrame(columns= bcolumns)

# %%
#script from MDAnalysis contacts that allows us to find contacts within the cutoff 
def contacts_within_cutoff(u, acidic, basic, radius=rad):
	timeseries = []
	for ts in u.trajectory:
		dist = contacts.distance_array(acidic.positions, basic.positions)
		n_contacts = contacts.contact_matrix(dist, radius).sum()
		timeseries.append([ts.frame, n_contacts])
	return np.array(timeseries)

# %%
for i in range(len(zz)):
	for j in range(len(thetas)):
		## First, theta
		theta = thetas[j]
		dcd_theta = dcd_thetas[j]
		## Then z
		z = zz[i]
		#defines theta and phi to one decimal point
		# theta = "%.2f" % theta
		# z = "%.2f" % z
		#adding theta and phi to the empty theta_phi list
		z_theta.append("z = " + z + " , θ = " + theta + "°")

		#defining file locations for PSF and DCD
		PSF_loc = "configurations/" + z + "_" + theta + "/2XEE__T3Q_" + z + "_" + theta + "__solvated_ionized.psf"
		DCD_loc = "configurations/" + z + "_" + theta + "/o/2XEE__T3Q_" + z + "_" + dcd_theta + ".dcd"
		print (DCD_loc)
		#start of the MDA script
		##define a string beforehand for the filename
		##change vscode to wrap lines
		u = mda.Universe(PSF_loc,DCD_loc)
		
		sel_basic = "(resname ARG or resname LYS) and (name NE or name NZ)"
		# sel_acidic = "(resname ASP or resname GLU) and (name OD1 or name OD2 or name OE1 or name OE2)"   
		sel_acidic = "index 2385 or index 2386 or index 2389 or index 2390" #O6, O7, O9, O10 of the phosphate
		
		acidic = u.select_atoms(sel_acidic) 
		basic = u.select_atoms(sel_basic) 
			
		ca = contacts_within_cutoff(u, acidic, basic, radius=rad)
		ca.shape
		ca_df = pd.DataFrame(ca, columns=['Frame', '# Contacts'])
		# print dataframe
		# display(ca_df)
		
		#calculate and store the total number of bonds in the simulation
		total_sb = ca_df['# Contacts'].sum()
		# print(total_sb)

		#add the total number of bonds in an array
		#adds the theta and z values to the hbond table
		# sb_z_theta = sb_z_theta.append([{'z':z, 'theta': theta, 'Bonds': total_sb}], ignore_index=True)
		sb_z_theta_columns = pd.DataFrame([{'z':z, 'theta': theta, 'Bonds': total_sb}])
		sb_z_theta = pd.concat([sb_z_theta_columns, sb_z_theta])

		#store data frame as a text file
		sb_array = ca_df.to_numpy()
		np.savetxt("configurations/" + z + "_" + theta + "/sbridges_MDA.txt", sb_array, fmt = "%d")

		# ca_df.head()
		# ca_df.plot(x='Frame')

		# plt.savefig("configurations/figures/" + z + "_" + theta + ".png")
		# plt.ylabel('# Contacts')

		#check total number of bonds per simulation, only uncomment when troubleshooting, slows down code
		# print(sb_z_theta)
# Out:
# configurations/-24.24_015/o/2XEE__T3Q_-24.24_15.dcd
# configurations/-24.24_045/o/2XEE__T3Q_-24.24_45.dcd
# configurations/-24.24_075/o/2XEE__T3Q_-24.24_75.dcd
# configurations/-24.24_105/o/2XEE__T3Q_-24.24_105.dcd
# configurations/-24.24_135/o/2XEE__T3Q_-24.24_135.dcd
# configurations/-24.24_165/o/2XEE__T3Q_-24.24_165.dcd
# configurations/-24.24_195/o/2XEE__T3Q_-24.24_195.dcd
# configurations/-24.24_225/o/2XEE__T3Q_-24.24_225.dcd
# configurations/-24.24_255/o/2XEE__T3Q_-24.24_255.dcd
# configurations/-24.24_285/o/2XEE__T3Q_-24.24_285.dcd
# configurations/-24.24_315/o/2XEE__T3Q_-24.24_315.dcd
# configurations/-24.24_345/o/2XEE__T3Q_-24.24_345.dcd
# configurations/-17.31_015/o/2XEE__T3Q_-17.31_15.dcd
# configurations/-17.31_045/o/2XEE__T3Q_-17.31_45.dcd
# configurations/-17.31_075/o/2XEE__T3Q_-17.31_75.dcd
# configurations/-17.31_105/o/2XEE__T3Q_-17.31_105.dcd
# configurations/-17.31_135/o/2XEE__T3Q_-17.31_135.dcd
# configurations/-17.31_165/o/2XEE__T3Q_-17.31_165.dcd
# configurations/-17.31_195/o/2XEE__T3Q_-17.31_195.dcd
# configurations/-17.31_225/o/2XEE__T3Q_-17.31_225.dcd
# configurations/-17.31_255/o/2XEE__T3Q_-17.31_255.dcd
# configurations/-17.31_285/o/2XEE__T3Q_-17.31_285.dcd
# configurations/-17.31_315/o/2XEE__T3Q_-17.31_315.dcd
# configurations/-17.31_345/o/2XEE__T3Q_-17.31_345.dcd
# configurations/-10.39_015/o/2XEE__T3Q_-10.39_15.dcd
# configurations/-10.39_045/o/2XEE__T3Q_-10.39_45.dcd
# configurations/-10.39_075/o/2XEE__T3Q_-10.39_75.dcd
# configurations/-10.39_105/o/2XEE__T3Q_-10.39_105.dcd
# configurations/-10.39_135/o/2XEE__T3Q_-10.39_135.dcd
# configurations/-10.39_165/o/2XEE__T3Q_-10.39_165.dcd
# configurations/-10.39_195/o/2XEE__T3Q_-10.39_195.dcd
# configurations/-10.39_225/o/2XEE__T3Q_-10.39_225.dcd
# configurations/-10.39_255/o/2XEE__T3Q_-10.39_255.dcd
# configurations/-10.39_285/o/2XEE__T3Q_-10.39_285.dcd
# configurations/-10.39_315/o/2XEE__T3Q_-10.39_315.dcd
# configurations/-10.39_345/o/2XEE__T3Q_-10.39_345.dcd
# configurations/-3.46_015/o/2XEE__T3Q_-3.46_15.dcd
# configurations/-3.46_045/o/2XEE__T3Q_-3.46_45.dcd
# configurations/-3.46_075/o/2XEE__T3Q_-3.46_75.dcd
# configurations/-3.46_105/o/2XEE__T3Q_-3.46_105.dcd
# configurations/-3.46_135/o/2XEE__T3Q_-3.46_135.dcd
# configurations/-3.46_165/o/2XEE__T3Q_-3.46_165.dcd
# configurations/-3.46_195/o/2XEE__T3Q_-3.46_195.dcd
# configurations/-3.46_225/o/2XEE__T3Q_-3.46_225.dcd
# configurations/-3.46_255/o/2XEE__T3Q_-3.46_255.dcd
# configurations/-3.46_285/o/2XEE__T3Q_-3.46_285.dcd
# configurations/-3.46_315/o/2XEE__T3Q_-3.46_315.dcd
# configurations/-3.46_345/o/2XEE__T3Q_-3.46_345.dcd
# configurations/03.46_015/o/2XEE__T3Q_03.46_15.dcd
# configurations/03.46_045/o/2XEE__T3Q_03.46_45.dcd
# configurations/03.46_075/o/2XEE__T3Q_03.46_75.dcd
# configurations/03.46_105/o/2XEE__T3Q_03.46_105.dcd
# configurations/03.46_135/o/2XEE__T3Q_03.46_135.dcd
# configurations/03.46_165/o/2XEE__T3Q_03.46_165.dcd
# configurations/03.46_195/o/2XEE__T3Q_03.46_195.dcd
# configurations/03.46_225/o/2XEE__T3Q_03.46_225.dcd
# configurations/03.46_255/o/2XEE__T3Q_03.46_255.dcd
# configurations/03.46_285/o/2XEE__T3Q_03.46_285.dcd
# configurations/03.46_315/o/2XEE__T3Q_03.46_315.dcd
# configurations/03.46_345/o/2XEE__T3Q_03.46_345.dcd
# configurations/10.39_015/o/2XEE__T3Q_10.39_15.dcd
# configurations/10.39_045/o/2XEE__T3Q_10.39_45.dcd
# configurations/10.39_075/o/2XEE__T3Q_10.39_75.dcd
# configurations/10.39_105/o/2XEE__T3Q_10.39_105.dcd
# configurations/10.39_135/o/2XEE__T3Q_10.39_135.dcd
# configurations/10.39_165/o/2XEE__T3Q_10.39_165.dcd
# configurations/10.39_195/o/2XEE__T3Q_10.39_195.dcd
# configurations/10.39_225/o/2XEE__T3Q_10.39_225.dcd
# configurations/10.39_255/o/2XEE__T3Q_10.39_255.dcd
# configurations/10.39_285/o/2XEE__T3Q_10.39_285.dcd
# configurations/10.39_315/o/2XEE__T3Q_10.39_315.dcd
# configurations/10.39_345/o/2XEE__T3Q_10.39_345.dcd
# configurations/17.31_015/o/2XEE__T3Q_17.31_15.dcd
# configurations/17.31_045/o/2XEE__T3Q_17.31_45.dcd
# configurations/17.31_075/o/2XEE__T3Q_17.31_75.dcd
# configurations/17.31_105/o/2XEE__T3Q_17.31_105.dcd
# configurations/17.31_135/o/2XEE__T3Q_17.31_135.dcd
# configurations/17.31_165/o/2XEE__T3Q_17.31_165.dcd
# configurations/17.31_195/o/2XEE__T3Q_17.31_195.dcd
# configurations/17.31_225/o/2XEE__T3Q_17.31_225.dcd
# configurations/17.31_255/o/2XEE__T3Q_17.31_255.dcd
# configurations/17.31_285/o/2XEE__T3Q_17.31_285.dcd
# configurations/17.31_315/o/2XEE__T3Q_17.31_315.dcd
# configurations/17.31_345/o/2XEE__T3Q_17.31_345.dcd
# configurations/24.24_015/o/2XEE__T3Q_24.24_15.dcd
# configurations/24.24_045/o/2XEE__T3Q_24.24_45.dcd
# configurations/24.24_075/o/2XEE__T3Q_24.24_75.dcd
# configurations/24.24_105/o/2XEE__T3Q_24.24_105.dcd
# configurations/24.24_135/o/2XEE__T3Q_24.24_135.dcd
# configurations/24.24_165/o/2XEE__T3Q_24.24_165.dcd
# configurations/24.24_195/o/2XEE__T3Q_24.24_195.dcd
# configurations/24.24_225/o/2XEE__T3Q_24.24_225.dcd
# configurations/24.24_255/o/2XEE__T3Q_24.24_255.dcd
# configurations/24.24_285/o/2XEE__T3Q_24.24_285.dcd
# configurations/24.24_315/o/2XEE__T3Q_24.24_315.dcd
# configurations/24.24_345/o/2XEE__T3Q_24.24_345.dcd

# %%
sb_z_theta.to_csv('00_ankyrin_sb_phos.csv')
sb = pd.read_csv('00_ankyrin_sb_phos.csv')


#load csv file
df_wide = sb.pivot_table( index='z', columns='theta', values='Bonds')

hm = sns.heatmap(df_wide, cmap="YlGnBu", linewidths=.003)
hm.invert_yaxis()
hm_fig = hm.get_figure() #this line may be an issue for the cluster, since there are no graphics
hm_fig.savefig("configurations/ankyrin_sb_phos_hm.png")
